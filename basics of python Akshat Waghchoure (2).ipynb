# %%
num = int(input('enter a number'))

if num > 1:
    for i in range(2, int(num**0.5)+1):
        if num % i == 0:
            print(num, 'is not a prime number')
            break
    else: 
        print(num, 'is a prime number')
else:
    print(num, 'is not a prime number')
# Out:
# enter a number 4
# 4 is not a prime number

# %%
### Exercise 2

# %%
import random


num1 = random.randint(1, 10)
num2 = random.randint(1, 10)

print('Multiply the numbers:', num1, 'and', num2)


user_answer = int(input('Enter the product: '))


if user_answer == num1 * num2:
    print('Correct')
else:
    print('Incorrect  The correct answer is:', num1 * num2)
# Out:
# Multiply the numbers: 2 and 5
# Enter the product:  10
# Correct

# %%
### exercise 3

# %%
# Program to print the squares of numbers from 100 to 200
# I am choosing ODD numbers for this program

print("Squares of odd numbers from 100 to 200:")

for num in range(100, 201):
    if num % 2 != 0:   
        print(num, "→", num ** 2)
# Out:
# Squares of odd numbers from 100 to 200:
# 101 → 10201
# 103 → 10609
# 105 → 11025
# 107 → 11449
# 109 → 11881
# 111 → 12321
# 113 → 12769
# 115 → 13225
# 117 → 13689
# 119 → 14161
# 121 → 14641
# 123 → 15129
# 125 → 15625
# 127 → 16129
# 129 → 16641
# 131 → 17161
# 133 → 17689
# 135 → 18225
# 137 → 18769
# 139 → 19321
# 141 → 19881
# 143 → 20449
# 145 → 21025
# 147 → 21609
# 149 → 22201
# 151 → 22801
# 153 → 23409
# 155 → 24025
# 157 → 24649
# 159 → 25281
# 161 → 25921
# 163 → 26569
# 165 → 27225
# 167 → 27889
# 169 → 28561
# 171 → 29241
# 173 → 29929
# 175 → 30625
# 177 → 31329
# 179 → 32041
# 181 → 32761
# 183 → 33489
# 185 → 34225
# 187 → 34969
# 189 → 35721
# 191 → 36481
# 193 → 37249
# 195 → 38025
# 197 → 38809
# 199 → 39601

# %%
### Exercise 4

# %%
room_charge_per_day = 2000
consultation_fee = 1500
lab_test_charge = 300


days_stayed = 4
lab_tests = 3
medicine_charges = 2400

# Step 1: Calculate total charges
room_total = room_charge_per_day * days_stayed
lab_total = lab_test_charge * lab_tests

# Step 2: Total before discount
total_before_discount = room_total + consultation_fee + lab_total + medicine_charges

# Step 3: Check and apply discount if applicable
if total_before_discount > 10000:
    discount = total_before_discount * 0.10
else:
    discount = 0

# Step 4: Final bill
final_bill = total_before_discount - discount

# Step 5: Display bill summary
print("------ Hospital Bill Summary ------")
print(f"Room Charges (₹{room_charge_per_day} x {days_stayed} days): ₹{room_total}")
print(f"Doctor Consultation Fee: ₹{consultation_fee}")
print(f"Lab Test Charges (₹{lab_test_charge} x {lab_tests} tests): ₹{lab_total}")
print(f"Medicine Charges: ₹{medicine_charges}")
print(f"Total Before Discount: ₹{total_before_discount}")
print(f"Discount Applied: ₹{discount}")
print(f"Final Bill Amount: ₹{final_bill}")
# Out:
# ------ Hospital Bill Summary ------
# Room Charges (₹2000 x 4 days): ₹8000
# Doctor Consultation Fee: ₹1500
# Lab Test Charges (₹300 x 3 tests): ₹900
# Medicine Charges: ₹2400
# Total Before Discount: ₹12800
# Discount Applied: ₹1280.0
# Final Bill Amount: ₹11520.0
